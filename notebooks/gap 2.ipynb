# %% [markdown]
# _____________
#
# # IMPORTS
# _____________

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gap_utils as gu

# %% [markdown]
# _____________
# # READ DATA
# ________

# %%
FILE_PATH = './NIFTY50_day.csv'
df = pd.read_csv(FILE_PATH)
print(len(df))
# Out:
# 5991

# %% [markdown]
# _________________
#
# # PLOT THE GAPS
# _________________

# %%
for yello in [25, 40, 60, 80]:
    print("/n/n")
    gu.plot_per_change_after_gap(df, gap_type='down', lower_per=yello)
# Out:
# /n/n
#
# RANGE OF GAP % CHANGE : 0.026% ----- 9.072%
#
# NO OF DATA POINTS : 1536
# /n/n
#
# RANGE OF GAP % CHANGE : 0.057% ----- 9.072%
#
# NO OF DATA POINTS : 1229
# /n/n
#
# RANGE OF GAP % CHANGE : 0.166% ----- 9.072%
#
# NO OF DATA POINTS : 819
# /n/n
#
# RANGE OF GAP % CHANGE : 0.398% ----- 9.072%
#
# NO OF DATA POINTS : 409

# %% [markdown]
# ___________________________
# ___________________________

# %% [markdown]
# _____________
#
# # IMPORTS
# _____________

# %%
import pandas as pd
import numpy as np
import gap_utils as gu

# %% [markdown]
# _____________
# # READ DATA
# ________

# %%
FILE_PATH = './NIFTY50_day.csv'
df = pd.read_csv(FILE_PATH)
print(len(df))
# Out:
# 5991

# %% [markdown]
# _________________
#
# # PLOT THE GAPS
# _________________

# %%
gu.plot_hist(df=df, gap_type='up', last_x_days=3000)

# %%
gu.plot_hist(df=df, gap_type='down', last_x_days=3000)
